# %% [markdown]
# # 25. Deep Learning of the Bulk Modulus
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rhennig/EMA6938/blob/main/Notebooks/25.DeepLearning-BulkModulus.ipynb)
#
# -----------------------------------------------------------------------------
# ## Fit data mining models to ~10,000 calculated bulk moduli from Materials Project
# -----------------------------------------------------------------------------
#
# **Time to complete: 30 minutes**
#
# The tutorial is based on the matminer tutorials from https://github.com/hackingmaterials/matminer_examples.
#
# This notebook is an example of using the MP data retrieval tool :code:`retrieve_MP.py` to retrieve computed bulk moduli from the
# <a href="https://materialsproject.org">Materials Project</a> database in the form of a pandas dataframe, using matminer's tools to populate the dataframe with descriptors/features from pymatgen, and then fitting regression models from the scikit-learn library to the dataset.
#
#
# ## Overview
#
# In this notebook, we will:
# 1. Load and examine a dataset in a pandas dataframe
# 2. Add descriptors to the dataframe using matminer
# 3. Train, compare, and visualize two machine learning methods with scikit-learn and Plotly.

# %% [markdown]
# ## Software installation
#
# To run this and other Python notebooks, I recommend using Jupyter. Here are the steps to install JupyterLab:
#
# - If you do not have Conda already installed on your computer, please follow the instructions at https://docs.conda.io/en/latest/miniconda.html. Then you can proceed to install JupyterLab, which will also install Python if it is not already installed.
#
# - `conda install jupyterlab`
#
# - `conda install ipywidgets`
#
# For the visualization, we are using Plotly. To install it:
#
# - `conda install plotly`
#
# - Install Node.js from https://nodejs.org/en/download/
#
# - `jupyter labextension install jupyterlab-plotly@4.13.0`

# %% [markdown]
# ## 1. Load and process data set
#
# We use matminer to load a data set of computed elastic properties of materials from MaterialsProject.
#
# ## 1.1 First load needed Python packages

# %%
# filter warnings messages from the notebook
import warnings
warnings.filterwarnings('ignore')

# Install pymatgen packages using pip in the current Jupyter kernel
# To use them, you may need to restart the kernel
import sys
# !{sys.executable} -m pip install pymatgen
# !{sys.executable} -m pip install matminer

import numpy as np
import pandas as pd

# Set pandas view options
pd.set_option('display.width', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Set path for saved images
import os
if not os.path.exists("images"):
    os.mkdir("images")
# Out:
# Requirement already satisfied: pymatgen in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (2022.10.22)
# Requirement already satisfied: monty>=3.0.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (2022.9.9)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (0.17.20)
# Requirement already satisfied: spglib>=2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (2.0.1)
# Requirement already satisfied: sympy in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (1.11.1)
# Requirement already satisfied: pybtex in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (0.24.0)
# Requirement already satisfied: mp-api>=0.27.3 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (0.29.3)
# Requirement already satisfied: plotly>=4.5.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (5.5.0)
# Requirement already satisfied: tabulate in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (0.8.9)
# Requirement already satisfied: numpy>=1.20.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (1.22.4)
# Requirement already satisfied: palettable>=3.1.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (3.3.0)
# Requirement already satisfied: tqdm in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (4.64.1)
# Requirement already satisfied: matplotlib>=1.5 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (3.4.3)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (3.1.6)
# Requirement already satisfied: networkx>=2.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (2.6.3)
# Requirement already satisfied: pandas in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (1.5.1)
# Requirement already satisfied: requests in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (2.27.1)
# Requirement already satisfied: scipy>=1.5.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen) (1.7.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen) (0.11.0)
# Requirement already satisfied: emmet-core>=0.36.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen) (0.38.6)
# Requirement already satisfied: msgpack in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen) (1.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen) (4.4.0)
# Requirement already satisfied: setuptools in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen) (60.0.3)
# Requirement already satisfied: six in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from plotly>=4.5.0->pymatgen) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from plotly>=4.5.0->pymatgen) (8.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests->pymatgen) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests->pymatgen) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests->pymatgen) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests->pymatgen) (1.26.7)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from ruamel.yaml>=0.17.0->pymatgen) (0.2.6)
# Requirement already satisfied: future in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from uncertainties>=3.1.4->pymatgen) (0.18.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pandas->pymatgen) (2021.3)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pybtex->pymatgen) (2.0.1)
# Requirement already satisfied: PyYAML>=3.01 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pybtex->pymatgen) (5.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from sympy->pymatgen) (1.2.1)
# Requirement already satisfied: pydantic==1.10.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from emmet-core>=0.36.4->mp-api>=0.27.3->pymatgen) (1.10.2)
# Requirement already satisfied: matminer in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (0.7.8)
# Requirement already satisfied: future>=0.18.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (0.18.2)
# Requirement already satisfied: pymatgen>=2022.5.17 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (2022.10.22)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (4.64.1)
# Requirement already satisfied: pymongo>=4.1.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (4.3.2)
# Requirement already satisfied: pandas>=1.4.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (1.5.1)
# Requirement already satisfied: jsonschema>=4.5.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (4.16.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (1.1.3)
# Requirement already satisfied: numpy>=1.22.3 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (1.22.4)
# Requirement already satisfied: requests>=2.27.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (2.27.1)
# Requirement already satisfied: sympy>=1.10.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (1.11.1)
# Requirement already satisfied: monty>=2022.4.26 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matminer) (2022.9.9)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from jsonschema>=4.5.1->matminer) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from jsonschema>=4.5.1->matminer) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from jsonschema>=4.5.1->matminer) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from jsonschema>=4.5.1->matminer) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pandas>=1.4.2->matminer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pandas>=1.4.2->matminer) (2021.3)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (3.1.6)
# Requirement already satisfied: scipy>=1.5.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (1.7.3)
# Requirement already satisfied: palettable>=3.1.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (3.3.0)
# Requirement already satisfied: networkx>=2.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (2.6.3)
# Requirement already satisfied: pybtex in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (0.24.0)
# Requirement already satisfied: matplotlib>=1.5 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (3.4.3)
# Requirement already satisfied: mp-api>=0.27.3 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (0.29.3)
# Requirement already satisfied: tabulate in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (0.8.9)
# Requirement already satisfied: plotly>=4.5.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (5.5.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (0.17.20)
# Requirement already satisfied: spglib>=2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymatgen>=2022.5.17->matminer) (2.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pymongo>=4.1.1->matminer) (2.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests>=2.27.1->matminer) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests>=2.27.1->matminer) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests>=2.27.1->matminer) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from requests>=2.27.1->matminer) (3.1)
# Requirement already satisfied: joblib>=1.0.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from scikit-learn>=1.1.0->matminer) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from scikit-learn>=1.1.0->matminer) (3.0.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from sympy>=1.10.1->matminer) (1.2.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=4.5.1->matminer) (3.6.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen>=2022.5.17->matminer) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen>=2022.5.17->matminer) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen>=2022.5.17->matminer) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from matplotlib>=1.5->pymatgen>=2022.5.17->matminer) (1.3.2)
# Requirement already satisfied: setuptools in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen>=2022.5.17->matminer) (60.0.3)
# Requirement already satisfied: msgpack in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen>=2022.5.17->matminer) (1.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen>=2022.5.17->matminer) (4.4.0)
# Requirement already satisfied: emmet-core>=0.36.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from mp-api>=0.27.3->pymatgen>=2022.5.17->matminer) (0.38.6)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from plotly>=4.5.0->pymatgen>=2022.5.17->matminer) (8.0.1)
# Requirement already satisfied: six in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from plotly>=4.5.0->pymatgen>=2022.5.17->matminer) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from ruamel.yaml>=0.17.0->pymatgen>=2022.5.17->matminer) (0.2.6)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pybtex->pymatgen>=2022.5.17->matminer) (2.0.1)
# Requirement already satisfied: PyYAML>=3.01 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from pybtex->pymatgen>=2022.5.17->matminer) (5.1.2)
# Requirement already satisfied: pydantic==1.10.2 in /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages (from emmet-core>=0.36.4->mp-api>=0.27.3->pymatgen>=2022.5.17->matminer) (1.10.2)

# %% [markdown]
# ## 1.1 Use matminer to obtain data from MP (automatically) in a "pandas" dataframe

# %%
from matminer.data_retrieval.retrieve_MP import MPDataRetrieval

api_key = '3rASVSCjrbXrI9Gn'   # Set your MP API key here. If set as an environment variable 'MAPI_KEY', set it to 'None'
mpr = MPDataRetrieval(api_key)     # Create an adapter to the MP Database.

# criteria is to get all entries with elasticity (K_VRH is bulk modulus) data
criteria = {'elasticity.K_VRH': {'$ne': None}}

# properties are the materials attributes we want
# See https://github.com/materialsproject/mapidoc for available properties you can specify
properties = ['pretty_formula', 'spacegroup.symbol', 'elasticity.K_VRH', 'formation_energy_per_atom', 'band_gap',
              'e_above_hull', 'density', 'volume', 'nsites']

# get the data!
df_mp = mpr.get_dataframe(criteria=criteria, properties=properties)
print('Number of bulk moduli extracted = ', len(df_mp))
# Out:
# 100%|██████████| 13172/13172 [00:14<00:00, 880.70it/s]
# Number of bulk moduli extracted =  13172

# %% [markdown]
# ## 1.2 Explore the dataset.
#
# The data set comes as a pandas DataFrame, which is a kind of "spreadsheet" object in Python. DataFrames have several useful methods you can use to explore and clean the data, some of which we'll explore below.

# %%
df_mp.head()
# Out:
#             pretty_formula spacegroup.symbol  elasticity.K_VRH  formation_energy_per_atom  band_gap  e_above_hull   density      volume  nsites
# material_id
# mp-1                    Cs             Im-3m               2.0                   0.038770    0.0000      0.038770  1.935039  114.051805       1
# mp-1002083          CsKICl            P4/mmm               3.0                  -1.834990    4.1193      0.062262  2.968000  187.068706       4
# mp-1002227            RbSb             Fm-3m               6.0                   0.322214    0.0000      0.741339  3.139285  109.614091       2
# mp-1006112           Na3Co             Fm-3m               9.0                   0.754160    0.0000      0.754160  2.156369   98.492949       4
# mp-10074             GeSe2             I-42d              10.0                  -0.254001    1.6631      0.000000  4.305992  177.823768       6

# %% [markdown]
# A pandas DataFrame includes a function called `describe()` that helps determine statistics for the various numerical / categorical columns in the data.

# %%
df_mp.describe()
# Out:
#        elasticity.K_VRH  formation_energy_per_atom      band_gap  e_above_hull       density        volume        nsites
# count      13172.000000               13172.000000  13172.000000  13172.000000  13172.000000  13172.000000  13172.000000
# mean         101.763210                  -0.847532      0.671362      0.096432      6.998474    141.718257      7.763134
# std           72.728987                   1.013787      1.405085      0.265915      3.385482    135.430947      7.881010
# min            0.000000                  -4.513010      0.000000      0.000000      0.023670      5.602384      1.000000
# 25%           45.000000                  -1.187357      0.000000      0.000000      4.474429     66.173948      4.000000
# 50%           85.000000                  -0.536274      0.000000      0.000000      6.613811    103.096526      5.000000
# 75%          146.000000                  -0.241757      0.556400      0.049605      8.842227    168.836892      9.000000
# max          591.000000                   4.412093     17.652600      4.412093     22.165012   3390.625722    160.000000

# %% [markdown]
# Sometimes, the `describe()` function will reveal outliers that indicate mistakes in the data. For example, negative hence unphysical minimum bulk/shear moduli or maximum bulk/shear moduli that are too high.
#
# The data looks ok at first glance; meaning that there are no clear problems with the ranges of the various properties. Therefore, and we won't filter out any data.
#
# Note that the `describe()` function only describes numerical columns by default.

# %% [markdown]
# ## 1.3 Filter out unstable entries and negative bulk moduli
#
# The data set above has some entries that correspond to thermodynamically or mechanically unstable materials. We filter these materials out using the distance from the convex hull and `K_VRH` (the Voight-Reuss-Hill average of the bulk modulus).

# %%
df = df_mp
df = df[df['elasticity.K_VRH'] > 0]
df = df[df['e_above_hull'] < 0.1]
df.describe()
# Out:
#        elasticity.K_VRH  formation_energy_per_atom      band_gap  e_above_hull       density        volume        nsites
# count      10801.000000               10801.000000  10801.000000  10801.000000  10801.000000  10801.000000  10801.000000
# mean          98.768355                  -0.956631      0.746245      0.011081      7.029388    151.915624      8.283585
# std           68.417595                   0.958849      1.465732      0.021934      3.340361    142.600369      8.305099
# min            1.000000                  -4.513010      0.000000      0.000000      0.107073      6.926148      1.000000
# 25%           45.000000                  -1.248292      0.000000      0.000000      4.501844     71.102107      4.000000
# 50%           84.000000                  -0.591223      0.000000      0.000000      6.679733    110.953545      6.000000
# 75%          142.000000                  -0.321101      0.859500      0.010991      8.880615    179.641389     10.000000
# max          551.000000                   0.099251     17.652600      0.099937     22.087251   3390.625722    160.000000

# %% [markdown]
# ## 1.4 Add descriptors/features
#
# Create a new desciptor for the volume per atom and add it to the pandas data frame.

# %%
# add volume per atom descriptor
df['vpa'] = df['volume']/df['nsites']

# explore columns
df.head()
# Out:
#             pretty_formula spacegroup.symbol  elasticity.K_VRH  formation_energy_per_atom  band_gap  e_above_hull   density      volume  nsites         vpa
# material_id
# mp-1                    Cs             Im-3m               2.0                   0.038770    0.0000      0.038770  1.935039  114.051805       1  114.051805
# mp-1002083          CsKICl            P4/mmm               3.0                  -1.834990    4.1193      0.062262  2.968000  187.068706       4   46.767177
# mp-10074             GeSe2             I-42d              10.0                  -0.254001    1.6631      0.000000  4.305992  177.823768       6   29.637295
# mp-1009490              O2              C2/m               3.0                   0.001712    1.6301      0.001712  1.140970   46.570259       2   23.285130
# mp-1014013               P              Pmna               2.0                   0.045053    0.8924      0.045053  0.384568  534.970620       4  133.742655

# %% [markdown]
# ## 1.5 Add several more descriptors using MatMiner’s pymatgen descriptor getter tools

# %%
from matminer.featurizers.composition import ElementProperty
from matminer.utils.data import PymatgenData
from pymatgen.core import Composition

df["composition"] = df['pretty_formula'].map(lambda x: Composition(x))

dataset = PymatgenData()
descriptors = ['row', 'group', 'atomic_mass',
               'atomic_radius', 'boiling_point', 'melting_point', 'X']
stats = ["mean", "std_dev"]

ep = ElementProperty(data_source=dataset, features=descriptors, stats=stats)
df = ep.featurize_dataframe(df, "composition")

#Remove NaN values
df = df.dropna()
df.head()
# Out:
# ElementProperty:   0%|          | 0/10801 [00:00<?, ?it/s]
# /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:212: UserWarning: No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:212: UserWarning: No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /Users/rhennig/opt/anaconda3/envs/tf2/lib/python3.8/site-packages/pymatgen/core/periodic_table.py:212: UserWarning: No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(

# %% [markdown]
# ## 2. Fit a Linear Regression model using SciKitLearn
#
# ## 2.1 Define what column is the target output, and what are the relevant descriptors
#
# The data set above has many columns - we won't need all this data for our modeling. We'll mainly be trying to predict `K_VRH` and `G_VRH` (the Voight-Reuss-Hill average of the bulk and shear modulus, respectively) and the `elastic_anisotropy`. We can drop most of the other output data.

# %%
# target output column
y = df['elasticity.K_VRH'].values

# possible descriptor columns
excluded = ["elasticity.K_VRH", "pretty_formula",
            "volume", "nsites", "spacegroup.symbol", "e_above_hull", "composition"]
X = df.drop(excluded, axis=1)
print("There are {} possible descriptors:\n\n{}".format(X.shape[1], X.columns.values))

# %% [markdown]
# ## 2.2 Fit the linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

lr = LinearRegression()

lr.fit(X, y)

# get fit statistics
print('Training R2 = ' + str(round(lr.score(X, y), 3)))
print('Training RMSE = %.3f' % np.sqrt(mean_squared_error(y_true=y, y_pred=lr.predict(X))))

# %% [markdown]
# ## 2.3 Cross validate the results

# %%
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict

# Use 10-fold cross validation (90% training, 10% test)
crossvalidation = KFold(n_splits=10, shuffle=True)

# compute cross validation scores for random forest model
r2_scores = cross_val_score(lr, X, y, scoring='r2', cv=crossvalidation, n_jobs=1)
print(r2_scores)
mse_scores = cross_val_score(lr, X, y, scoring='neg_mean_squared_error', cv=crossvalidation, n_jobs=1)
rmse_scores = [np.sqrt(abs(s)) for s in mse_scores]

print('Cross-validation results:')
print('Folds: %i, mean R2: %.3f' % (len(r2_scores), np.mean(np.abs(r2_scores))))
print('Folds: %i, mean RMSE: %.3f' % (len(rmse_scores), np.mean(np.abs(rmse_scores))))

# %% [markdown]
# ## 2.4 Scatter density plot the results with Plotly and kernel density estimate¶

# %%
import plotly.graph_objects as PlotlyFig
from scipy import stats

# a line to represent a perfect model with 1:1 prediction
xy_params = {'x_col': [0, 400],
             'y_col': [0, 400],
             'color': 'black',
             'mode': 'lines',
             'legend': None,
             'text': None,
             'size': None}

xx=y
yy=lr.predict(X)

# Calculate the point density
kde = stats.gaussian_kde([xx,yy])
zz = kde([xx,yy])

# Sort the points by density, so that the densest points are plotted last
idx = zz.argsort()
xx, yy, z = xx[idx], yy[idx], zz[idx]

fig = PlotlyFig.Figure(data=PlotlyFig.Scattergl(
    x=xx,
    y=yy,
    mode='markers',
    marker=dict(
        size=5,
        color=z, #set color equal to a variable
        colorscale='Viridis', # one of plotly colorscales
    ),
    text=df['pretty_formula']
))

fig.update_layout(xaxis_title='DFT (MP) bulk modulus (GPa)',
                  yaxis_title='Predicted bulk modulus (GPa)',
                  title='Linear regression',
                  width=800,
                  height=800,
                  font=dict(family="Helvetica",
                            size=18, color="black")
    )

fig.update_yaxes(scaleanchor="x")

fig.add_trace(PlotlyFig.Scatter(x=[0,400], y=[0,400],
                    mode='lines'))

fig.update_layout(xaxis=dict(range=[0, 400]),
                  yaxis=dict(range=[0, 400]),
                  showlegend=False)

fig.show()

# %% [markdown]
# Great! We just fit a linear regression model to pymatgen features using matminer and sklearn. Now let’s use a Random Forest model to examine the importance of our features.
#
# ## 3. Follow similar steps for a neural network model
#
# ### 3.1 Split the data into training and testing set and fit neural network model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.neural_network import MLPRegressor
ann = MLPRegressor(hidden_layer_sizes=(100,), learning_rate_init=0.001, random_state=1, max_iter=200)
ann.fit(X_train, y_train)

# get fit statistics
print('training R2 = ' + str(round(ann.score(X_train, y_train), 3)))
print('training RMSE = %.3f' % np.sqrt(mean_squared_error(y_true=y_train, y_pred=ann.predict(X_train))))
print('test R2 = ' + str(round(ann.score(X_test, y_test), 3)))
print('test RMSE = %.3f' % np.sqrt(mean_squared_error(y_true=y_test, y_pred=ann.predict(X_test))))

# %% [markdown]
# ### 3.2 Cross-validate the results to plot the model

# %%
# compute cross validation scores for random forest model
scores = cross_val_score(ann, X, y, scoring='neg_mean_squared_error', cv=crossvalidation, n_jobs=-1)

rmse_scores = [np.sqrt(abs(s)) for s in scores]
print('Cross-validation results:')
print('Folds: %i, mean RMSE: %.3f' % (len(scores), np.mean(np.abs(rmse_scores))))

# %% [markdown]
# ### 3.3 Plot the neural network model

# %%
# a line to represent a perfect model with 1:1 prediction
xy_params = {'x_col': [0, 400],
             'y_col': [0, 400],
             'color': 'black',
             'mode': 'lines',
             'legend': None,
             'text': None,
             'size': None}

xx=y
yy=cross_val_predict(ann, X, y, cv=crossvalidation, n_jobs=-1)

# Calculate the point density
kde = stats.gaussian_kde([xx,yy])
zz = kde([xx,yy])

# Sort the points by density, so that the densest points are plotted last
idx = zz.argsort()
xx, yy, z = xx[idx], yy[idx], zz[idx]

fig = PlotlyFig.Figure(data=PlotlyFig.Scattergl(
    x=xx,
    y=yy,
    mode='markers',
    marker=dict(
        size=5,
        color=z, #set color equal to a variable
        colorscale='Viridis', # one of plotly colorscales
    ),
    text=df['pretty_formula']
))

fig.update_layout(xaxis_title='DFT (MP) bulk modulus (GPa)',
                  yaxis_title='Predicted bulk modulus (GPa)',
                  title='Neural Network Model',
                  width=800,
                  height=800,
                  font=dict(family="Helvetica",
                            size=18, color="black")
    )

fig.update_yaxes(scaleanchor="x")

fig.add_trace(PlotlyFig.Scatter(x=[0,400], y=[0,400],
                    mode='lines'))

fig.update_layout(xaxis=dict(range=[0, 400]),
                  yaxis=dict(range=[0, 400]),
                  showlegend=False)

fig.show()

# %% [markdown]
# This looks better than the linear regression model and reflects the improved cross-validated R2 and RMSE.
#
# You could (optionally) visualize the training error by replacing the code `cross_val_predict(ann, X, y, cv=crossvalidation)` in the above cell with `ann.predict(X)` to visualize the training error. While that would look better still, it would not be an accurate representation of your prediction error.
#
# ## 3.4 Visualize the distribution of training and testing errors

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

ann = MLPRegressor(hidden_layer_sizes=(100,), learning_rate_init=0.001,random_state=1, max_iter=200)
ann.fit(X_train, y_train)

# get fit statistics
print('training R2 = ' + str(round(ann.score(X_train, y_train), 3)))
print('training RMSE = %.3f' % np.sqrt(mean_squared_error(y_true=y_train, y_pred=ann.predict(X_train))))
print('test R2 = ' + str(round(ann.score(X_test, y_test), 3)))
print('test RMSE = %.3f' % np.sqrt(mean_squared_error(y_true=y_test, y_pred=ann.predict(X_test))))

# %%
import plotly.graph_objects as PlotlyFig

data_train=y_train-ann.predict(X_train)
data_test=y_test-ann.predict(X_test)

fig = PlotlyFig.Figure()
fig.add_trace(PlotlyFig.Histogram(x=data_train,
                                  name='Training',
                                  histnorm='probability',
                                  xbins=dict(
                                      start=-50.0,
                                      end=50,
                                      size=2
                                  )))

fig.add_trace(PlotlyFig.Histogram(x=data_test,
                                  name='Testing',
                                  histnorm='probability',
                                  xbins=dict(
                                      start=-50.0,
                                      end=50,
                                      size=2
                                  )))

fig.update_layout(xaxis_title='Bulk modulus prediction residual (GPa)',
                  yaxis_title='Probability',
                  title='Neural Network Regression Residuals',
                  barmode='stack',
                  width=800,
                  height=600,
                  font=dict(family="Helvetica",
                            size=18, color="black")
    )

fig.show()

# %% [markdown]
# ### 3.5 Optimize Hyperparameters using Crossvalidation

# %%
from sklearn.model_selection import GridSearchCV
ann=MLPRegressor()

param_grid = {'hidden_layer_sizes': [(100), (200), (100,100)],
          'activation': ['relu'],
          'alpha': [0.001],
          'solver': ['adam'],
          'max_iter': [200, 500]}
#           'learning_rate': ['constant','adaptive'],

grid_search = GridSearchCV(
    ann,
    param_grid,
    cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_result = grid_search.fit(X, y)

# %%
# Optimial hyperparameters 
tuned_parameters = grid_search.best_params_
print(tuned_parameters)

# %%
tuned_ann = MLPRegressor(**tuned_parameters)

# compute cross validation scores for random forest model
scores = cross_val_score(tuned_ann, X, y, scoring='neg_mean_squared_error',
                         cv=crossvalidation, n_jobs=-1)

rmse_scores = [np.sqrt(abs(s)) for s in scores]
print('Cross-validation results:')
print('Folds: %i, mean RMSE: %.3f' % (len(scores), np.mean(np.abs(rmse_scores))))

# %% [markdown]
# # Concluding Remarks
#
# As we see, for this materials dataset, the neural network model does better than the simple linear regression. However, this comes at the significant cost of an dramatically increased number of parameters.
#
# Furthermore, we had previously applied the random forest and gradient boosted trees models. Looking back at those results, both tree-based models actually performed better than the neural network model.
#
# The take-home message is that the most complex model is not always the best. It is often wise to start with simple machine learning models such as linear regression, random forest and gradient boosted trees. Use cross-validation to optimize hyperparameters and include regularization. Then move to more complex models such as kernel-ridge regression and support vector regression before trying out deep neural network models.
